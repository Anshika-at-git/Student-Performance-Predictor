# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('student-mat.csv', sep=';')
df.head()

# %%
data = df[['studytime', 'failures', 'absences', 'G1', 'G2', 'G3']]
data.head()

# %%
x = data.drop('G3', axis=1)
y = data['G3']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)

# %%
print("R2 score:",r2_score(y_test, y_pred))
print("Mean squared error:", mean_squared_error(y_test, y_pred))
# Out:
# R2 score: 0.7821754247320557
# Mean squared error: 4.466503212015601

# %%
new_student = [[2, 0, 4, 14, 15]]
print("Predicted final score:", model.predict(new_student))

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
sns.barplot(x='studytime', y='G3', data=data)
plt.title("Average final grades vs studytime")
plt.xlabel("Weekly Study Time")
plt.ylabel("Final Grade (G3)")
plt.show()

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.scatterplot(x='G1', y='G3', data=data)
plt.title("G1 vs Final Grade")

plt.subplot(1,2,2)
sns.scatterplot(x='G2', y='G3', data=data)
plt.title("G2 vs Final Grade")

plt.tight_layout()
plt.show()
